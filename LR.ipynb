# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import tree

iris = datasets.load_iris()
sepal = iris.data[:, :2]
petal = iris.data[:, 2:]
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
def classify_LR(features_train, labels_train):
    from sklearn import linear_model
    clf = linear_model.LogisticRegression(solver='lbfgs',multi_class='multinomial')
    clf.fit(features_train, labels_train)
    return clf

def classify_DT(features_train, labels_train):
    from sklearn import tree
    clf = tree.DecisionTreeClassifier(max_depth=3)
    clf = clf.fit(X_train, y_train)
    return clf

# %%
# logistic regression 
clf = classify_LR(X_train,y_train)
clf.score(X_test, y_test)*100
# Out:
# 95.55555555555556

# %%
# decision tree
clf = classify_DT(X_train,y_train)
print(clf.score(X_test, y_test)*100)

import graphviz 

dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=iris.feature_names,  
                      class_names=iris.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# 95.55555555555556
